# %%
import csv

file = './input/testing_data.csv'

with open(file, 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    your_list = list(reader)

new_list= []

for row in your_list:
    temp_list_row = []
    dollar = False
    for j in range(1,len(row)):
        temp_list_col = []
        
        if " $ " in row[j]:
            dollar = True
            temp_list_col = row[j].split(" $ ")
            
            for item in temp_list_col:
                temp_list_row.append([row[0],item,j])
                
        elif " $ " not in row[j] and dollar == True:
            temp_list_row.append([row[0],row[j],j])
        
    if temp_list_row:
        row_no = len(new_list)
        new_list.append([0]*len(row))
        for x in range(1,len(row)):
            first = True
            for item in temp_list_row:
                if x == item[2]:
                    if first == True:
                        new_list[row_no][0] = item[0]
                        new_list[row_no][x] = item[1]
                        first = False
                    else:
                        new_list.append([0]*len(row))
                        new_list[len(new_list)-1][0] = item[0]
                        for y in range(1,len(row)):
                            if y != x:
                                new_list[len(new_list)-1][y] = ""
                            else:
                                new_list[len(new_list)-1][y] = item[1]    
    else:
        new_list.append(row)

new_file = 'output_data_2.csv'

file = open(new_file, "w", encoding='utf-8', newline='')
writer = csv.writer(file, delimiter = ",")

for list_ in new_list:
    writer.writerow(list_)
file.close()
print(new_list)
# Out:
# [['ResourceID', 'Subject(s)', 'Bibliographic Item Description text', 'Bibliographic Source Title', 'Author'], ['1', 'History', "L'histiore du christianisme dans l'île de Socotorah. Revue illustrée de la Terre Sainte et de l'Orient catholique", "L'histiore du Christianisme dans l'île de Socotorah", 'Caillaud, F. R. du'], ['2', 'History', "Un successeur de l'Apôtre Saint Thomas, Frère Antonio Loureiro, de L'Ordre de Saint Francois de l'Observance, premier Missionnaire latin dans l'île Socotorah.", "Un successeur de l'Apôtre Saint Thomas, Frère Antonio Loureiro, de L'Ordre de Saint Francois de l'Observance, premier Missionnaire latin dans l'île Socotorah.", 'Caillaud, F. R. du'], ['3', 'History', '', "L'île de Socotorah", 'Candolle, A. de'], ['3', 'Geography', '', '', ''], ['4', 'History', '', "L'île de Socotora", 'Capitaine, M.H.'], ['4', 'Geography', '', '', ''], ['5', 0, 0, 0, 'Cary, M.'], ['5', '', '', '', 'Warmington, E.H.'], ['6', 'History', 'Text with introduction, translation and commentary by Lionel Casson; pp xvii + 320; 17 maps; See pp 18-19,46,101, 133, 164-169, 285, 292', 'The Periplus Maris Erythraei', 'Casson, L. (ed.)'], ['7', 0, 0, 0, 'Cerný, V.'], ['7', '', '', '', 'Pereira, L.'], ['7', '', '', '', 'Kujanová, M.'], ['7', '', '', '', 'Vasíková, A.'], ['7', '', '', '', 'Hájek, M.'], ['7', '', '', '', 'Morris, M.'], ['7', '', '', '', 'Mulligan, C.J. '], ['8', 'History', '', 'Socotra - A Natural History of the Islands and Their People', 'Cheung, C.'], ['8', 'Archaeology', '', '', ''], ['8', 'Anthropology', '', '', ''], ['8', '', '', '', 'De Vantier, L.'], ['9', 'Anthropology', 'In Naumkin, V.V. Island of the Phoenix', 'Human Cranial Remains from Socotra', 'Chistov, Yu.K.'], ['10', 'Archaeology', 'In: Hadramaut. Volume 1. "Vostochnaya Literatura"(Moscow). pps 503-526; 3 tables, 3 figures', 'The First Palaeoanthropological Materials from the Island of Socotra', 'Chistov, Yu.K.'], ['10', 'Anthropology', '', '', '']]

# %%
import pandas as pd 


df = pd.read_csv('./input/testing_data.csv')
df
# Out:
#    ResourceID                            Subject(s)  \
# 0           1                               History
# 1           2                               History
# 2           3                   History $ Geography
# 3           4                   History $ Geography
# 4           5                             Geography
# 5           6                               History
# 6           7                          Anthropology
# 7           8  History $ Archaeology $ Anthropology
# 8           9                          Anthropology
# 9          10            Archaeology $ Anthropology
#
#                  Bibliographic Item Description text  \
# 0  L'histiore du christianisme dans l'île de Soco...
# 1  Un successeur de l'Apôtre Saint Thomas, Frère ...
# 2                                                NaN
# 3                                                NaN
# 4                                          With maps
# 5  Text with introduction, translation and commen...
# 6                                                NaN
# 7                                                NaN
# 8             In Naumkin, V.V. Island of the Phoenix
# 9  In: Hadramaut. Volume 1. "Vostochnaya Literatu...
#
#                           Bibliographic Source Title  \
# 0  L'histiore du Christianisme dans l'île de Soco...
# 1  Un successeur de l'Apôtre Saint Thomas, Frère ...
# 2                                 L'île de Socotorah
# 3                                  L'île de Socotora
# 4                              The Ancient Explorers
# 5                       The Periplus Maris Erythraei
# 6  Out of Arabia - The Settlement of Island Soqot...
# 7  Socotra - A Natural History of the Islands and...
# 8                 Human Cranial Remains from Socotra
# 9  The First Palaeoanthropological Materials from...
#
#                                               Author
# 0                                 Caillaud, F. R. du
# 1                                 Caillaud, F. R. du
# 2                                    Candolle, A. de
# 3                                    Capitaine, M.H.
# 4                        Cary, M. $ Warmington, E.H.
# 5                                   Casson, L. (ed.)
# 6  Cerný, V. $ Pereira, L. $ Kujanová, M. $ Vasík...
# 7                        Cheung, C. $ De Vantier, L.
# 8                                     Chistov, Yu.K.
# 9                                     Chistov, Yu.K.

# %%
import pandas as pd 


df = pd.read_csv('output_data_2.csv')
df
# Out:
#     ResourceID    Subject(s)  \
# 0            1       History
# 1            2       History
# 2            3       History
# 3            3     Geography
# 4            4       History
# 5            4     Geography
# 6            5             0
# 7            5           NaN
# 8            6       History
# 9            7             0
# 10           7           NaN
# 11           7           NaN
# 12           7           NaN
# 13           7           NaN
# 14           7           NaN
# 15           7           NaN
# 16           8       History
# 17           8   Archaeology
# 18           8  Anthropology
# 19           8           NaN
# 20           9  Anthropology
# 21          10   Archaeology
# 22          10  Anthropology
#
#                   Bibliographic Item Description text  \
# 0   L'histiore du christianisme dans l'île de Soco...
# 1   Un successeur de l'Apôtre Saint Thomas, Frère ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                   0
# 7                                                 NaN
# 8   Text with introduction, translation and commen...
# 9                                                   0
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20             In Naumkin, V.V. Island of the Phoenix
# 21  In: Hadramaut. Volume 1. "Vostochnaya Literatu...
# 22                                                NaN
#
#                            Bibliographic Source Title              Author
# 0   L'histiore du Christianisme dans l'île de Soco...  Caillaud, F. R. du
# 1   Un successeur de l'Apôtre Saint Thomas, Frère ...  Caillaud, F. R. du
# 2                                  L'île de Socotorah     Candolle, A. de
# 3                                                 NaN                 NaN
# 4                                   L'île de Socotora     Capitaine, M.H.
# 5                                                 NaN                 NaN
# 6                                                   0            Cary, M.
# 7                                                 NaN    Warmington, E.H.
# 8                        The Periplus Maris Erythraei    Casson, L. (ed.)
# 9                                                   0           Cerný, V.
# 10                                                NaN         Pereira, L.
# 11                                                NaN        Kujanová, M.
# 12                                                NaN        Vasíková, A.
# 13                                                NaN           Hájek, M.
# 14                                                NaN          Morris, M.
# 15                                                NaN     Mulligan, C.J.
# 16  Socotra - A Natural History of the Islands and...          Cheung, C.
# 17                                                NaN                 NaN
# 18                                                NaN                 NaN
# 19                                                NaN      De Vantier, L.
# 20                 Human Cranial Remains from Socotra      Chistov, Yu.K.
# 21  The First Palaeoanthropological Materials from...      Chistov, Yu.K.
# 22                                                NaN                 NaN

# %% [markdown]
# ## Old

# %%
import csv

file = 'example_data.csv'

with open(file, 'r') as f:
    reader = csv.reader(f)
    your_list = list(reader)

i=0
new_list= []

for row in your_list:
    temp_list = []
    if " $ " in row[1]:
        temp_list = row[1].split(" $ ")
    else:
        new_list.append(row)
    
    i=0
    for item in temp_list:
        if i == 0:
            new_list.append([row[0], item, row[2]])
        else:
            new_list.append([row[0], item, ""])
        i += 1

new_file = 'output_data.csv'

file = open(new_file, "w", encoding='utf-8', newline='')
writer = csv.writer(file, delimiter = ",")

for list_ in new_list:
    writer.writerow(list_)
file.close()
# Out:
# [['ResourceID', 'Column 1', 'Column 2'], ['1', 'A', 'X'], ['2', 'B', 'Y'], ['2', 'C', ''], ['2', 'D', ''], ['3', 'E', 'Z'], ['3', 'F', '']]
# 'file = open(new_file, "w", encoding=\'utf-8\', newline=\'\')\nwriter = csv.writer(file, delimiter = ",")\n\nfor list_ in new_list:\n    writer.writerow(list_)\nfile.close()'
